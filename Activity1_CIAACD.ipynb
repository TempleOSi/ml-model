# %% [markdown]
# # Actividad 3
#
# ## Integrantes
# Eduardo Joel Cortez Valente
# a01746664@tec.mx
#
# Ana Martínez Barbosa
# a01382889@tec.mx
#
# Jorge Isidro Blanco Martínez
# a01745907@tec.mx
#
# José María Ibarra Pérez
# a01706970@tec.mx
#
# Maximiliano Benítez Ahumada
# a01752791@tec.mx

# %%
#Install kaggle
# !pip install -q kaggle

# %%
#Libraries
from google.colab import files
import pandas as pd
import numpy as np
import seaborn as sns

# %%
files.upload()
# Out:
#      <input type="file" id="files-91da94ad-7879-497e-a148-a9eaa41ce8bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91da94ad-7879-497e-a148-a9eaa41ce8bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Configure kaggle library

# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/kaggle.json

# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets list
# Out:
# ref                                                                   title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/countries-of-the-world-2023                          Global Country Information Dataset 2023             23KB  2023-07-08 20:37:33          11251        449  1.0
# nelgiriyewithana/global-youtube-statistics-2023                       Global YouTube Statistics 2023                      60KB  2023-07-28 15:36:38           3382        131  1.0
# joebeachcapital/global-earth-temperatures                             Global Earth Temperatures                           33KB  2023-08-09 06:21:51            714         29  1.0
# ...

# %%
#Example download a database
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
#   0% 0.00/199k [00:00<?, ?B/s]
# 100% 199k/199k [00:00<00:00, 94.4MB/s]

# %%
#Unzip the archive
# !unzip house-prices-advanced-regression-techniques.zip -d "/content/kaggledb"
# Out:
# Archive:  house-prices-advanced-regression-techniques.zip
#   inflating: /content/kaggledb/data_description.txt
#   inflating: /content/kaggledb/sample_submission.csv
#   inflating: /content/kaggledb/test.csv
#   inflating: /content/kaggledb/train.csv

# %%
#Load database
df = pd.read_csv("/content/kaggledb/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Obtain Datatypes
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# Las categorias son las siguientes:
#
# | Variable       | Descripción               | Tipo de Dato | Tipo de Variable  |
# |----------------|---------------------------|--------------|------------------------|
# | Id             | Id unico del dato  | Entero | Numérico discreto |
# | MSSubClass  | Tipo de vivienda | Entero | Numérico discreto|
# | MSZoning     |    Clasificacion de la zona | Objeto | Categórica nominal |
# | LotFrontage  | Distancia en pies que conecta a la propiedad con la calle | Flotante |Numérico continuo |
# | LotArea  | Área del lote en pies cuadrados | Entero | Numérico discreto
# | Street | Calle donde está ubicada la vivienda | Objeto | Categórica nominal |
# | Alley | Tipo de callejón de entrada |  Objeto | Categórica nominal |
# | LotShape | Forma general de la propiedad | Objeto | Categórica nominal |
# | LandContour | llanura de la propiedad | Objeto | Categórica nominal |
# | Utilities |     Utilidades disponibles   | Objeto | Categórica nominal |
# | LotConfig|  Configuración de lote      | Objeto| Categórica nominal |
# | LandSlope|  Pendiente      | Objeto| Categórica nominal |
# | Neighborhood|  Vecindario | Objeto| Categórica nominal |
# | Condition1| Proximidad a calle principal 1      | Objeto| Categórica nominal |
# | Condition2|  Proximidad a calle principal 2       | Objeto| Categórica nominal |
# | BldgType| Tipo de construcción     | Objeto| Categórica nominal |
# | HouseStyle | Tipo de vivienda | object | Categórica Nominal |
# | OverallQual | Calidad general del material y del acabado | int64 | Numérica Ordinal |
# | OverallCond | Calificación de condición general | int64 | Numérica Ordinal |
# | YearBuilt | Fecha de construcción original | int64 | Numérica Discreta |
# | YearRemodAdd | Año de remodelación | int64 | Numérica Discreta |
# | RoofStyle | Tipo de techo | object | Categórica Nominal |
# | RoofMatl | Material del techo | object | Categórica Nominal |
# | Exterior1st | Revestimiento (material) del exterior | object | Categórica Nominal |
# | Exterior2nd | Revestimiento (material) del exterior, si es más de un material | object | Categórica Nominal |
# | MasVnrType | Tipo de chapa de mampostería | object | Categórica Nominal |
# | MasVnrArea | Área de revestimiento de mampostería en pies cuadrados | float64 | Numérica Continua |
# | ExterQual | Calidad de materiales exteriores | object | Categórica Ordinal |
# | ExterCond | Estado actual del material en el exterior | object | Categórica Ordinal |
# | Foundation | Tipo de cimiento | object | Categórica Nominal |
# | BsmtQual | Altura del sótano | object | Categórica Ordinal |
# | BsmtCond | Estado general del sótano | object | Categórica Ordinal |
# | BsmtExposure | Muros de sótano a nivel de salida o jardín | object | Categórica Ordinal |
# | Heating        | Calefacción               | Objeto       | Categórica nominal    |
# | HeatingQC      | Calidad de Calefacción    | Objeto       | Categórica ordinal   |
# | CentralAir     | Aire Acondicionado Central| Objeto        | Categórica nominal    |
# | Electrical     | Sistema Eléctrico         | Objeto        | Categórica nominal    |
# | 1stFlrSF       | Área del Primer Piso      | Entero       | Numérico  discreto  |
# | 2ndFlrSF       | Área del Segundo Piso     | Entero       | Numérico  discreto  |
# | LowQualFinSF   | Área de Acabado de Baja Calidad | Entero   | Numérico  discreto  |
# | GrLivArea      | Área de Espacio Habitacional (sobre nivel del suelo) | Entero | Numérico  discreto  |
# | BsmtFullBath   | Baños Completos en Sótano  | Entero       | Numérico  discreto |
# | BsmtHalfBath   | Medios Baños en Sótano     | Entero       | Numérico  discreto  |
# | FullBath       | Baños Completos            | Entero       | Numérico  discreto  |
# |HalfBath |  Medios baños |int | Numérico discreto |
# |BedroomAbvGr  | número de cuartos | int | Numérico discreto |
# |KitchenAbvGr   |  número cocinas | int | Numérico discreto |
# |KitchenQual   | Calidad cocina | object | Categórico ordinal |
# |TotRmsAbvGrd  | Total cuartos | int | Numérico discreto|
# |Functional   | Home functionality | object | Categorica dicreta |
# |Fireplaces   | Cantidad fireplaces | int| Numérico discreto |
# |FireplaceQu   | calidad fireplace | object |  Ctegórico nominal |
# |GarageType  |Ubicación del garage | object | Categórico nominal |
# |GarageYrBlt   | Años que lleva construido | int | Numérico continuo |
# |GarageFinish | Acabados interior | object | Categórica nominal |
# |GarageCars  |	Tamaño garage por cantidad coches | int | Numérico discreto |
# |WoodDeckSF | Área de la cubierta | int64 | Númerico discreto |
# |OpenPorchSF | Área del porche | int64 | Numérico discreto |
# |EnclosedPorch | Área de porche cerrado | int64 | Numérico discreto |
# |3SsnPorch | Área de porche de tres estaciones | int64 | Numérico discreto |
# |ScreenPorch | Área de porche con malla | int64 | Numérico discreto |
# |PoolArea | Área de alberca | int64 | Numérico discreto |
# |PoolQC |Calidad de alberca | object | Categórico ordinal |
# |Fence | Calidad de barda | object | Categórico ordinal |
# |MiscFeature | Características misceláneas | object | Categórico nominal |
# |MiscVal | Valor de las características misceláneas | int64 | Numérico discreto |
# |MoSold | Mes de venta | int64 | Categórico nominal |
# |YrSold | Año de venta | int64 | Categórico nominal |
# |SaleType | Tipo de venta | object | Categórico nominal |
# |SaleCondition | Condición de venta | object | Categórico nominal |
# |SalePrice | Precio de venta | int64 | Numérico discreto |
